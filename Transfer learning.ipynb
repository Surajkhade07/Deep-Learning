# %%
# !pip install tensorflow_hub
# Out:
# Collecting tensorflow_hub
#   Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow_hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow_hub) (5.29.5)
# Collecting tf-keras>=2.14.1 (from tensorflow_hub)
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\lenovo\anaconda34\lib\site-packages (from tf-keras>=2.14.1->tensorflow_hub) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.4.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (24.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\anaconda34\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.44.0)
# Requirement already satisfied: rich in c:\users\lenovo\anaconda34\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (13.7.1)
# Requirement already satisfied: namex in c:\users\lenovo\anaconda34\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.1.0)
# Requirement already satisfied: optree in c:\users\lenovo\anaconda34\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda34\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda34\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda34\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda34\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.4.1)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda34\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (10.4.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda34\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\anaconda34\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda34\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda34\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda34\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow_hub) (0.1.0)
# Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 796.8 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.7 MB 796.8 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 780.2 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 780.2 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 780.2 kB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 572.0 kB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 572.0 kB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 572.0 kB/s eta 0:00:02
#    ------------------------------ --------- 1.3/1.7 MB 524.3 kB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 524.3 kB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 524.3 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 493.3 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 493.3 kB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.7 MB 493.3 kB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 444.9 kB/s eta 0:00:00
# Installing collected packages: tf-keras, tensorflow_hub
# Successfully installed tensorflow_hub-0.16.1 tf-keras-2.20.1

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
import PIL.Image as Image

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential 
from tensorflow import keras
import os
import tensorflow_hub as hub
import numpy as np

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
IMAGE_SHAPE=(224,224)
classifier = tf.keras.Sequential([
    hub.KerasLayer(
        "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/classification/4",
        input_shape=IMAGE_SHAPE+(3,)
    )
])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 IMAGE_SHAPE=(224,224)
#       2 classifier = tf.keras.Sequential([
# ----> 3     hub.KerasLayer(
#       4         "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/classification/4",
#       5         input_shape=IMAGE_SHAPE+(3,)
#       6     )
#       7 ])
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\keras_layer.py:165, in KerasLayer.__init__(self, handle, trainable, arguments, _sentinel, tags, signature, signature_outputs_as_dict, output_key, output_shape, load_options, **kwargs)
#     161   self._output_shape = data_structures.NoDependency(
#     162       _convert_nest_to_shapes(output_shape))
#     164 self._load_options = load_options
# --> 165 self._func = load_module(handle, tags, self._load_options)
#     166 self._is_hub_module_v1 = getattr(self._func, "_is_hub_module_v1", False)
#     168 # Update with the defaults when using legacy TF1 Hub format.
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\keras_layer.py:467, in load_module(handle, tags, load_options)
#     465     except ImportError:  # Expected before TF2.4.
#     466       set_load_options = load_options
# --> 467 return module_v2.load(handle, tags=tags, options=set_load_options)
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\module_v2.py:100, in load(handle, tags, options)
#      98 if not isinstance(handle, str):
#      99   raise ValueError("Expected a string, got %s" % handle)
# --> 100 module_path = resolve(handle)
#     101 is_hub_module_v1 = tf.io.gfile.exists(_get_module_proto_path(module_path))
#     102 if tags is None and is_hub_module_v1:
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\module_v2.py:55, in resolve(handle)
#      31 def resolve(handle):
#      32   """Resolves a module handle into a path.
#      33
#      34   This function works both for plain TF2 SavedModels and the legacy TF1 Hub
#    (...)
#      53     A string representing the Module path.
#      54   """
# ---> 55   return registry.resolver(handle)
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\registry.py:49, in MultiImplRegister.__call__(self, *args, **kwargs)
#      47 for impl in reversed(self._impls):
#      48   if impl.is_supported(*args, **kwargs):
# ---> 49     return impl(*args, **kwargs)
#      50   else:
#      51     fails.append(type(impl).__name__)
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\compressed_module_resolver.py:81, in HttpCompressedFileResolver.__call__(self, handle)
#      77   response = self._call_urlopen(request)
#      78   return resolver.DownloadManager(handle).download_and_uncompress(
#      79       response, tmp_dir)
# ---> 81 return resolver.atomic_download(handle, download, module_dir,
#      82                                 self._lock_file_timeout_sec())
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\resolver.py:421, in atomic_download(handle, download_fn, module_dir, lock_file_timeout_sec)
#     419 logging.info("Downloading TF-Hub Module '%s'.", handle)
#     420 tf.compat.v1.gfile.MakeDirs(tmp_dir)
# --> 421 download_fn(handle, tmp_dir)
#     422 # Write module descriptor to capture information about which module was
#     423 # downloaded by whom and when. The file stored at the same level as a
#     424 # directory in order to keep the content of the 'model_dir' exactly as it
#    (...)
#     429 # module caching protocol and no code in the TF-Hub library reads its
#     430 # content.
#     431 _write_module_descriptor_file(handle, module_dir)
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\compressed_module_resolver.py:77, in HttpCompressedFileResolver.__call__.<locals>.download(handle, tmp_dir)
#      71   return resolver.DownloadManager(handle).download_and_uncompress(
#      72       response, tmp_dir
#      73   )
#      75 request = urllib.request.Request(
#      76     self._append_compressed_format_query(handle))
# ---> 77 response = self._call_urlopen(request)
#      78 return resolver.DownloadManager(handle).download_and_uncompress(
#      79     response, tmp_dir)
#
# File ~\anaconda34\Lib\site-packages\tensorflow_hub\resolver.py:528, in HttpResolverBase._call_urlopen(self, request)
#     526   return urllib.request.urlopen(request)
#     527 else:
# --> 528   return urllib.request.urlopen(request, context=self._context)
#
# File ~\anaconda34\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\anaconda34\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\anaconda34\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\anaconda34\Lib\urllib\request.py:553, in OpenerDirector.error(self, proto, *args)
#     551     http_err = 0
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#     555     return result
#
# File ~\anaconda34\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\anaconda34\Lib\urllib\request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     742 fp.read()
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File ~\anaconda34\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\anaconda34\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\anaconda34\Lib\urllib\request.py:553, in OpenerDirector.error(self, proto, *args)
#     551     http_err = 0
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#     555     return result
#
# File ~\anaconda34\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\anaconda34\Lib\urllib\request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     742 fp.read()
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File ~\anaconda34\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\anaconda34\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\anaconda34\Lib\urllib\request.py:559, in OpenerDirector.error(self, proto, *args)
#     557 if http_err:
#     558     args = (dict, 'default', 'http_error_default') + orig_args
# --> 559     return self._call_chain(*args)
#
# File ~\anaconda34\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\anaconda34\Lib\urllib\request.py:639, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     638 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
hen=Image.open('hen.jpeg').resize((224,224))

# %%
hen
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
hen=np.array(hen)/255.0
hen
# Out:
# array([[[0.87843137, 0.86666667, 0.84705882],
#         [0.87843137, 0.86666667, 0.84705882],
#         [0.87843137, 0.86666667, 0.84705882],
#         ...,
#         [0.80392157, 0.83137255, 0.87058824],
#         [0.79607843, 0.82352941, 0.8627451 ],
#         [0.78039216, 0.81176471, 0.85098039]],
#
#        [[0.88235294, 0.87058824, 0.85098039],
#         [0.87843137, 0.86666667, 0.84705882],
#         [0.87843137, 0.86666667, 0.84705882],
#         ...,
#         [0.80392157, 0.81960784, 0.8627451 ],
#         [0.79607843, 0.81960784, 0.85882353],
#         [0.78039216, 0.80784314, 0.84705882]],
#
#        [[0.87843137, 0.86666667, 0.84705882],
#         [0.87843137, 0.86666667, 0.84705882],
#         [0.87843137, 0.86666667, 0.84705882],
#         ...,
#         [0.79607843, 0.81176471, 0.84705882],
#         [0.79215686, 0.80784314, 0.84313725],
#         [0.78823529, 0.80392157, 0.83921569]],
#
#        ...,
#
#        [[0.17647059, 0.19607843, 0.17254902],
#         [0.15294118, 0.16470588, 0.14117647],
#         [0.1372549 , 0.15686275, 0.1372549 ],
#         ...,
#         [0.15686275, 0.19607843, 0.19607843],
#         [0.14509804, 0.18823529, 0.18823529],
#         [0.13333333, 0.17254902, 0.16862745]],
#
#        [[0.35686275, 0.31764706, 0.28235294],
#         [0.1372549 , 0.14509804, 0.12156863],
#         [0.16862745, 0.17647059, 0.15294118],
#         ...,
#         [0.14509804, 0.18431373, 0.17647059],
#         [0.14509804, 0.18823529, 0.19215686],
#         [0.13333333, 0.17254902, 0.16862745]],
#
#        [[0.40392157, 0.34901961, 0.31372549],
#         [0.13333333, 0.1254902 , 0.10980392],
#         [0.12156863, 0.1254902 , 0.10588235],
#         ...,
#         [0.15294118, 0.18431373, 0.18039216],
#         [0.15686275, 0.19607843, 0.2       ],
#         [0.16078431, 0.2       , 0.2       ]]])

# %%
classifier.predict(hen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 classifier.predict(hen)
#
# NameError: name 'classifier' is not defined
